# %% [markdown]
#                                             MINI PROJECT OF CREDIT SCORE WORTHY BY CLASSIFICATION

# %%
import numpy as np
import pandas as pd

# %% [markdown]
#                                                       ANALYZING DATA

# %%
data =pd.read_csv('test.csv')

# %%
data.head()
# Out:
#        ID Customer_ID      Month             Name  Age          SSN  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24_  821-00-0265
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0  Scientist      19114.12            1824.843333                  3  ...
# 1  Scientist      19114.12            1824.843333                  3  ...
# 2  Scientist      19114.12            1824.843333                  3  ...
# 3  Scientist      19114.12                    NaN                  3  ...
# 4    _______      34847.84            3037.986667                  2  ...
#
#    Num_Credit_Inquiries  Credit_Mix Outstanding_Debt Credit_Utilization_Ratio  \
# 0                2022.0        Good           809.98                35.030402
# 1                   4.0        Good           809.98                33.053114
# 2                   4.0        Good           809.98                33.811894
# 3                   4.0        Good           809.98                32.430559
# 4                   5.0        Good           605.03                25.926822
#
#        Credit_History_Age Payment_of_Min_Amount Total_EMI_per_month  \
# 0   22 Years and 9 Months                    No           49.574949
# 1  22 Years and 10 Months                    No           49.574949
# 2                     NaN                    No           49.574949
# 3   23 Years and 0 Months                    No           49.574949
# 4   27 Years and 3 Months                    No           18.816215
#
#    Amount_invested_monthly                 Payment_Behaviour  \
# 0       236.64268203272135    Low_spent_Small_value_payments
# 1       21.465380264657146  High_spent_Medium_value_payments
# 2       148.23393788500925   Low_spent_Medium_value_payments
# 3        39.08251089460281  High_spent_Medium_value_payments
# 4       39.684018417945296   High_spent_Large_value_payments
#
#       Monthly_Balance
# 0  186.26670208571772
# 1  361.44400385378196
# 2  264.67544623342997
# 3  343.82687322383634
# 4   485.2984336755923
#
# [5 rows x 27 columns]

# %%
                 # CONVERT SOME STRING VALUE TO FLOAT


def clean_and_convert(value):
    if isinstance(value, str):
        # Replace '18_' with '18' and attempt conversion to float
        cleaned_value = value.replace('_', '')
        try:
            return float(cleaned_value)
        except ValueError:
            return value  # Return original value if conversion fails
    return value  # Return value unchanged if it's not a string

# Apply the function to each cell in the DataFrame
data = data.applymap(clean_and_convert)
# Out:
# C:\Users\dmins\AppData\Local\Temp\ipykernel_14916\1130658897.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data = data.applymap(clean_and_convert)

# %%
data.shape
# Out:
# (50000, 27)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        50000 non-null  object
#  1   Customer_ID               50000 non-null  object
#  2   Month                     50000 non-null  object
#  3   Name                      44985 non-null  object
#  4   Age                       50000 non-null  float64
#  5   SSN                       50000 non-null  object
#  6   Occupation                50000 non-null  object
#  7   Annual_Income             50000 non-null  float64
#  8   Monthly_Inhand_Salary     42502 non-null  float64
#  9   Num_Bank_Accounts         50000 non-null  int64
#  10  Num_Credit_Card           50000 non-null  int64
#  11  Interest_Rate             50000 non-null  int64
#  12  Num_of_Loan               50000 non-null  float64
#  13  Type_of_Loan              44296 non-null  object
#  14  Delay_from_due_date       50000 non-null  int64
#  15  Num_of_Delayed_Payment    46502 non-null  float64
#  16  Changed_Credit_Limit      50000 non-null  object
#  17  Num_Credit_Inquiries      48965 non-null  float64
#  18  Credit_Mix                50000 non-null  object
#  19  Outstanding_Debt          50000 non-null  float64
#  20  Credit_Utilization_Ratio  50000 non-null  float64
#  21  Credit_History_Age        45530 non-null  object
#  22  Payment_of_Min_Amount     50000 non-null  object
#  23  Total_EMI_per_month       50000 non-null  float64
#  24  Amount_invested_monthly   47729 non-null  float64
#  25  Payment_Behaviour         50000 non-null  object
#  26  Monthly_Balance           49438 non-null  float64
# dtypes: float64(11), int64(4), object(12)
# memory usage: 10.3+ MB

# %%
data = data.dropna()

# %%
data.isnull().sum().head()   # no null value in this dataset
# Out:
# ID             0
# Customer_ID    0
# Month          0
# Name           0
# Age            0
# dtype: int64

# %%
data['Credit_Mix'].value_counts()
# Out:
# Credit_Mix
# Standard    9757
# Good        5802
# Bad         5654
# _           5245
# [_             1
# Name: count, dtype: int64

# %%
data = data[data['Credit_Mix'] != '_']     # for cleaning the data(entire row of '_' ).

# %%
data['Credit_Mix'].value_counts()
# Out:
# Credit_Mix
# Standard    9757
# Good        5802
# Bad         5654
# [_             1
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (21214, 27)

# %%
data['Credit_Mix']=data['Credit_Mix'].map({     # we basically assign the values of standard as 1, Good as 2,  Poor as 0 for a numeric value for better interpretation
    'Standard': 1,
    'Good' :  2,
    'Bad' : 0
})

# %%
data['Credit_Mix']
# Out:
# 0        2.0
# 1        2.0
# 4        2.0
# 5        2.0
# 9        2.0
#         ...
# 49990    2.0
# 49992    0.0
# 49993    0.0
# 49994    0.0
# 49997    2.0
# Name: Credit_Mix, Length: 21214, dtype: float64

# %%
data['Credit_Mix'].value_counts()
# Out:
# Credit_Mix
# 1.0    9757
# 2.0    5802
# 0.0    5654
# Name: count, dtype: int64

# %%
data.shape          # we have much only left 15559 rows after data interpretation
# Out:
# (21214, 27)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21214 entries, 0 to 49997
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        21214 non-null  object
#  1   Customer_ID               21214 non-null  object
#  2   Month                     21214 non-null  object
#  3   Name                      21214 non-null  object
#  4   Age                       21214 non-null  float64
#  5   SSN                       21214 non-null  object
#  6   Occupation                21214 non-null  object
#  7   Annual_Income             21214 non-null  float64
#  8   Monthly_Inhand_Salary     21214 non-null  float64
#  9   Num_Bank_Accounts         21214 non-null  int64
#  10  Num_Credit_Card           21214 non-null  int64
#  11  Interest_Rate             21214 non-null  int64
#  12  Num_of_Loan               21214 non-null  float64
#  13  Type_of_Loan              21214 non-null  object
#  14  Delay_from_due_date       21214 non-null  int64
#  15  Num_of_Delayed_Payment    21214 non-null  float64
#  16  Changed_Credit_Limit      21214 non-null  object
#  17  Num_Credit_Inquiries      21214 non-null  float64
#  18  Credit_Mix                21213 non-null  float64
#  19  Outstanding_Debt          21214 non-null  float64
#  20  Credit_Utilization_Ratio  21214 non-null  float64
#  21  Credit_History_Age        21214 non-null  object
#  22  Payment_of_Min_Amount     21214 non-null  object
#  23  Total_EMI_per_month       21214 non-null  float64
#  24  Amount_invested_monthly   21214 non-null  float64
#  25  Payment_Behaviour         21214 non-null  object
#  26  Monthly_Balance           21214 non-null  float64
# dtypes: float64(12), int64(4), object(11)
# memory usage: 4.5+ MB

# %%
data['Num_of_Loan']
# Out:
# 0        4.0
# 1        4.0
# 4        1.0
# 5        1.0
# 9        3.0
#         ...
# 49990    3.0
# 49992    5.0
# 49993    5.0
# 49994    5.0
# 49997    2.0
# Name: Num_of_Loan, Length: 21214, dtype: float64

# %% [markdown]
#                                                         DATA VISUALIZATION

# %%
import plotly.express as px

# %%
data = pd.DataFrame(data)

# Create the box plot
fig = px.box(data, x='Occupation', color='Credit_Mix', title='Distribution of Credit Mix by Occupation',
             color_discrete_map={'Bad':'green',
                                  'Standard' :'red',
                                  'Good': 'blue' })


# Show the plot
fig.show()

# %% [markdown]
#                                           BUILDING THE MODEL

# %%
from sklearn.model_selection import train_test_split
x = np.array(data[['Annual_Income','Num_Bank_Accounts','Num_Credit_Card','Num_of_Loan','Delay_from_due_date','Num_of_Delayed_Payment',
                  'Outstanding_Debt','Monthly_Balance']])
y = np.array(data[['Credit_Mix']])

# %%
data['Credit_Mix'].shape
# Out:
# (21214,)

# %%
print(x.shape) 
print(y.shape)
# Out:
# (21214, 8)
# (21214, 1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
  # this is for the NaN value in a y_test
non_nan_values = y_test[~np.isnan(y_test)]    
unique, counts = np.unique(non_nan_values, return_counts=True)
most_frequent_value = unique[np.argmax(counts)]

# Fill NaN values with the most frequent value
y_test= np.where(np.isnan(y_test), most_frequent_value, y_test)

# %%
import numpy as np

# Check for NaN values
print("NaN in y_test:", np.any(np.isnan(y_test)))
print("NaN in y_predict:", np.any(np.isnan(y_predict)))
# Out:
# NaN in y_test: False
# NaN in y_predict: False

# %%
from sklearn.ensemble import RandomForestClassifier
Model = RandomForestClassifier(criterion='entropy',n_estimators=150)

# %%
Model.fit(x_train,y_train)
# Out:
# C:\Users\dmins\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(criterion='entropy', n_estimators=150)

# %%
y_predict=Model.predict(x_test)

# %% [markdown]
#                                                  ACCURACY OF THE MODEL

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_predict))
# Out:
# 0.9263157894736842
